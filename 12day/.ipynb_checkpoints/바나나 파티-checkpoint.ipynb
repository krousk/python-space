# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

from PIL import Image

from wordcloud import WordCloud 
from konlpy.tag import Okt    


from collections import Counter

from IPython.display import set_matplotlib_formats

from ckonlpy.tag import Twitter

# %%
with open( "바나나파티를 위하여 (심소하).txt", 'r') as f:
    lists = f.readlines()

# %%
tagger=Twitter()
#tagger.add_dictionary(['예알바','칼레건','요울바','타이런','메세르','켈로스','켈루스','츠질라크'],'Noun')
# Out:
# C:\python\anaconda3\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
#okt = Okt()
morphs = []
 
for sentence in lists:
    morphs.append( tagger.pos( sentence ) )

# %%
noun_adj_adv_list=[]
 
for sentence in morphs :
    for word, tag in sentence :
        if tag in [ 'Noun' ] and ( "말" not in word )  and ( "은" not in word ) and ( "때" not in word ) and ( "려고" not in word ) and ( "처럼" not in word ) and ( "면서" not in word ) and ( "때문" not in word ) and ( "까지" not in word ) and ( "거" not in word ) and ( "더" not in word ) and ( "었다" not in word ) and ( "그녀" not in word ) and ( "그" not in word ) and ( "것" not in word ) and ( "내" not in word ) and ( "나" not in word ) and ( "수" not in word ) :
            noun_adj_adv_list.append( word )
            
print( noun_adj_adv_list )
# Out:
# ['부', '안녕', '첫사랑', '섹스', '사람', '이기', '섹스', '반복', '앞', '섹스', '파티', '파티', '섹스', '어감', '데', '귀', '여운', '느낌', '마음', '파티', '성인', '고작', '넉', '달이', '뿐', '스무', '살', '전', '모든', '경험', '올해', '넉', '달', '간의', '경험', '변화', '남중', '남고', '출신', '십대', '게임', '공부', '외', '관심', '당시', '여자', '존재', '관측', '존재', '하늘', '술', '담배', '고', '숙박', '공식', '적', '허락', '성인', '자마자', '머릿속', '여자', '가득', '정확', '여자', '파티', '망상', '이윽고', '현재', '숨', '밥', '심지어', '서서', '바람', '파티', '상', '상하', '지경', '이르렀다', '갑자기', '변화', '사람', '러하', '듯', '역시', '극적', '사건', '누군가', '사연', '긴밀', '술', '잔뜩', '자취', '방', '날', '밤', '별', '돌', '색욕', '악마', '바', '를', '소환', '사건', '원인', '지목', '논리', '적', '개연', '성', '답', '이지', '바', '조우', '극적', '어도', '일종', '덤', '색욕', '악마', '언급', '하니', '퍽', '흥미', '변화', '직접', '적', '관계', '음으로', '시간', '날', '이야기', '도록', '지금', '부터', '변화', '이유', '처음', '부터', '끝', '구구절', '절', '설명', '루하', '아주', '길', '바란', '당사자', '경험', '요약', '일부분', '라서', '액자', '또', '다른', '작품', '탄생', '공', '쓰레기', '경험', '간', '이해', '대신', '만', '남', '게', '발단', '행운', '로부터', '시작', '문제', '과',
# ...

# %%
count = Counter( noun_adj_adv_list )
words = dict( count.most_common(50) ) #common 안에 집어넣으면 출력숫자 제한 가능.
words
# Out:
# {'유라': 497,
#  '사람': 485,
#  '안': 458,
#  '정윤': 437,
#  '너': 415,
#  '생각': 407,
#  '여자': 363,
#  '경이': 340,
#  '네': 314,
#  '못': 247,
#  '이삭': 234,
#  '어서': 231,
#  '사랑': 224,
#  '록': 219,
#  '눈': 219,
#  '게': 217,
#  '시간': 213,
#  '적': 203,
#  '술': 196,
#  '뒤': 194,
#  '우리': 193,
#  '다가': 190,
#  '남자': 189,
#  '일': 186,
#  '알': 185,
#  '이': 181,
#  '손': 181,
#  '어요': 181,
#  '파티': 173,
#  '아무': 173,
#  '보고': 171,
#  '담배': 168,
#  '뭐': 167,
#  '왜': 167,
#  '고': 165,
#  '얼굴': 161,
#  '경의': 160,
#  '지금': 159,
#  '오늘': 159,
#  '청춘': 146,
#  '감정': 145,
#  '줄': 140,
#  '두': 134,
#  '해': 134,
#  '집': 134,
#  '해도': 132,
#  '마음': 131,
#  '소리': 126,
#  '몸': 125,
#  '앞': 123}

# %%
matplotlib.rc( 'font',family = 'Malgun Gothic' )
set_matplotlib_formats( 'retina' )
matplotlib.rc( 'axes', unicode_minus = False )

# %%
wordcloud = WordCloud( font_path = 'C:/Windows/Fonts/malgun.ttf',
                      background_color='black',colormap = "Accent_r",
                      width=1500, height=1000).generate_from_frequencies( words )

plt.imshow( wordcloud )
plt.axis( 'off' )
plt.show()
